# %%
#OPEN FILES AND IMPORT LIBRARIES
import pandas as pd
import re
import matplotlib.pyplot as plt

df0 = pd.read_excel("Data Analyst Report Writer Sample Dataset.xlsx", index_col=0)
#df0 = pd.read_csv("Data Analyst Report Writer Sample Dataset.csv",index_col=0)

# %%
#FIRST FIVE LINES
#-----------------
df0.head(5)
# Out:
#                                                   skill_title  DocumentId  \
# ObjectId
# 5bd23e5214b35001c88804db  computer software technical support   201163998
# 5aca7f0d0cbf2c0460d62041                  equipment servicing   201163998
# 5add7a07dccd3b50f3bf5a69    laboratory equipment installation   201163998
# 5acbe821c2c2f1713ae19ccf               laboratory maintenance   201163998
# 5aa76e2653b12204854a64f0     mechanical equipment maintenance   201163998
#
#                          Type   OriginalTitle        CreationDate  \
# ObjectId
# 5bd23e5214b35001c88804db  job  Lab Technician 2020-03-10 05:29:20
# 5aca7f0d0cbf2c0460d62041  job  Lab Technician 2020-03-10 05:29:20
# 5add7a07dccd3b50f3bf5a69  job  Lab Technician 2020-03-10 05:29:20
# 5acbe821c2c2f1713ae19ccf  job  Lab Technician 2020-03-10 05:29:20
# 5aa76e2653b12204854a64f0  job  Lab Technician 2020-03-10 05:29:20
#
#                             OriginalCompanyName  RangeFrom  RangeTo  \
# ObjectId
# 5bd23e5214b35001c88804db  University of Toronto    48650.0  48650.0
# 5aca7f0d0cbf2c0460d62041  University of Toronto    48650.0  48650.0
# 5add7a07dccd3b50f3bf5a69  University of Toronto    48650.0  48650.0
# 5acbe821c2c2f1713ae19ccf  University of Toronto    48650.0  48650.0
# 5aa76e2653b12204854a64f0  University of Toronto    48650.0  48650.0
#
#                                  ClusteredTitle OriginalLocation  \
# ObjectId
# 5bd23e5214b35001c88804db  laboratory technician      Toronto, ON
# 5aca7f0d0cbf2c0460d62041  laboratory technician      Toronto, ON
# 5add7a07dccd3b50f3bf5a69  laboratory technician      Toronto, ON
# 5acbe821c2c2f1713ae19ccf  laboratory technician      Toronto, ON
# 5aa76e2653b12204854a64f0  laboratory technician      Toronto, ON
#
#                           OriginalSalary CountryCode     City SalaryParsed  \
# ObjectId
# 5bd23e5214b35001c88804db  $48,650 a year          CA  Toronto      b'\x01'
# 5aca7f0d0cbf2c0460d62041  $48,650 a year          CA  Toronto      b'\x01'
# 5add7a07dccd3b50f3bf5a69  $48,650 a year          CA  Toronto      b'\x01'
# 5acbe821c2c2f1713ae19ccf  $48,650 a year          CA  Toronto      b'\x01'
# 5aa76e2653b12204854a64f0  $48,650 a year          CA  Toronto      b'\x01'
#
#                          State  Complexity  importance
# ObjectId
# 5bd23e5214b35001c88804db    ON         5.0    0.804382
# 5aca7f0d0cbf2c0460d62041    ON         6.0    0.841847
# 5add7a07dccd3b50f3bf5a69    ON         5.0    1.023003
# 5acbe821c2c2f1713ae19ccf    ON         5.0    1.128249
# 5aa76e2653b12204854a64f0    ON         6.0    0.946662

# %%
#SHAPE OF THE DATASET
#---------------------
df0.shape
# Out:
# (231713, 17)

# %%
#Check that the data types are correct
'''Agregation vectors should be floats or ints not objects, if object then there may be bad characters'''
df0.dtypes
# Out:
# skill_title                    object
# DocumentId                      int64
# Type                           object
# OriginalTitle                  object
# CreationDate           datetime64[ns]
# OriginalCompanyName            object
# RangeFrom                     float64
# RangeTo                       float64
# ClusteredTitle                 object
# OriginalLocation               object
# OriginalSalary                 object
# CountryCode                    object
# City                           object
# SalaryParsed                   object
# State                          object
# Complexity                    float64
# importance                    float64
# dtype: object

# %%
#Name of columns and index of each column:
''' This function provides a clean output of columns and indexes'''

def col(dfs):
    list_col = list(dfs.columns.values)
    list_number_col = []
    zip_list = []
    for i in range(0, len(list_col)):
        list_number_col.append(i)
    zip_list = list(zip(list_number_col,list_col))
    #[(0, 'event_date'), (1, 'id'), (2, 'dimension_1')]
    for i in zip_list:
        a = i[0]
        b = i[1]
        print(str(a) + "|" +  b)
print(col(df0))
# Out:
# 0|skill_title
# 1|DocumentId
# 2|Type
# 3|OriginalTitle
# 4|CreationDate
# 5|OriginalCompanyName
# 6|RangeFrom
# 7|RangeTo
# 8|ClusteredTitle
# 9|OriginalLocation
# 10|OriginalSalary
# 11|CountryCode
# 12|City
# 13|SalaryParsed
# 14|State
# 15|Complexity
# 16|importance
# None

# %%
#TRANSFORM BROKEN COLUMNS:
#-------------------------
'''Elements that have varying data types e.g.(strings and/or floats), lets change them to strings.'''

#TRANSFORM OBJECT INTO DATES:
#----------------------------

# %%
#Check unique values of columns
'''Use this line to have a close look at the data'''
set(list(df0.iloc[:,3]))
#len(sorted(set(list(df0.iloc[:,5])), reverse=True))

#check = sorted(set(list(df0.iloc[:,5])), reverse=True)
#print("Length of list : ",len(check))
#print("TOP 3 VALUES OF LIST : ",(check[0:3]))
#print("BOT 3 VALUES OF LIST : ",(check[-3:]))
# Out:
# {'Clinical Research Professional â€“ Ethics & Regulatory Affairs',
#  nan,
#  'Lab technician - Lifelabs',
#  'Research Associate - Valid Security',
#  'Medical â€‹ â€‹Scientific â€‹ â€‹Liaison',
#  'Material Handler/Order Picker',
#  'Manager, Clinical Programs',
#  'Director, Customer Experience',
#  'Registered Nurse Medical',
#  'Medical Clinical Research',
#  'Research Assistant - Medical Markets',
#  'Clinical Trial Assistant (CTA)',
#  'Medical Science Liaison - Alberta and Sasketchwan',
#  'Assistant Professor in Research - Wayne State University',
#  'Bilingual Clinical Research Associate II (Unblinded/ Drug Accountability)',
#  'Associate Chemist',
#  'QA/ RA Pharmacovigilance',
#  'Regional Medical Advisor - Denver Based',
#  'RN, BScN, CPMHN(C)',
#  'Principal Clinical Demand and Supply Manager, iNeST',
#  'Administration Assistant',
#  'Animal Health Technician (Sherbrooke) 1',
#  'Research Volunteer CAMH - Temerty Centre For Therapeutic Brain Intervention',
#  'Teaching Assistant (McGill University), Researcher (Memory-Lab), MSc, MD.',
#  'LPN ( Infusion clinic/ home pharma',
#  'Clinician/ Medical Monitor',
#  'Laboratory Manager/Technician - Glycobiology Lab, Ryerson University',
#  'Project administrator - clinical trials',
#  'Associate Research Scientist, Microbiology and Immunology - University of Michigan Med School',
#  'Epidemiologist - April 24, 2020',
#  'World Wide Medical Leader (WWML)',
#  'Registered Nurse (Casual)',
#  'ORTHOPEDIC RESEARCH ASSOCIATE - Sunnybrook Research Institute',
#  'Director, Clinical Trials Administration',
#  'Sr Associate Scientist - Clinical Cytometry Liaison',
#  'Undergraduate Research Associate - Michigan State University',
#  'Medical Oncologist - BC Cancer Prince George',
#  '6236 Trial Master File Specialist On Hold',
#  'Laboratory Assistant - Part Time Regular Float - Surrey/Delta, BC',
#  'Lab Patient Technician Float - ON',
#  'Licensed Practical Nurse / Medical Technologist (Screening)',
#  'Temporary full time LVN',
#  'Quality Control Supervisor',
#  'Intern',
#  'Lab Technologist - I',
#  'Scientist, Analytical Development',
#  'Medical Director, US Medical Lead â€“ Inflammation (Tezepelumab)',
#  'RN Supervisor - Per Diem',
#  'Research Director at Zoetis',
#  'Medical Director, Clinical Development',
#  'Director - Quality Assurance and Regulatory Compliance - ApoPharma Inc. (Innovative Drug Division of Apotex Inc',
#  'Medical Laboratory Technologist I - Alberta Health Services',
#  'System Engineer - Baxter',
#  'Clinical Research Technician',
#  'Lab Patient Technician <1 year- -',
#  'Strategic Collaborations Lead (Research Networks)',
#  'Clinical Trials Coordinator',
#  'Quality Assurance Analyst',
#  'Dietary Aide - 50% - Marshfield',
#  'SAS Clinical Data Manager',
#  'Computational Chemist',
#  'Medical Science Liaison - Neurosciences - Ontario 12 months contract',
#  'Vice President/Oncology Medicine Development Leader - TIM3',
#  'Director-Cancer Research/Henry Ford Cancer Institute',
#  'Senior Business Intelligence (BI) Developer',
#  'Medical Science Liaison â€“ Oncology',
#  'Telehealth Nurse Educator',
#  'Medical Technologist - Gift of Life Michigan',
#  'MSL, Western Canada',
#  'Defence Scientist',
#  'Senior Project/Product Manager',
#  'Research & Development Coordinator (13 month contract)',
#  'Clinical Project Manager, Clinical Operations',
#  'Technologist, Upstream',
#  "Research Assistant - Women's College Hospital",
#  'Immunochemistry Analyst',
#  'Research Assistant III - McMaster University',
#  'Senior Field Application Scientist at Thermo Fisher Scientific',
#  'Medical Director/Medical Science Director-Manager, Neuroscience Pipeline',
#  'Medical Affairs Executive Director - Georgia (Ecosystem)',
#  'LPN - John D. Dingell Dept',
#  'ASSOCIATE SCIENTIST - SANOFI PASTEUR',
#  'Clinical Research Assistant - Inflamax Research Inc',
#  'Senior Clinical Research Scientist - Oncology - Home Based',
#  'Research Associate - LBA',
#  'Senior Scientist',
#  'Director of Research Training - William Beaumont School of Medicine (OUWB), Oakland University',
#  'Research Associate 1/2, Biology',
#  'Laboratory Assistant - Surrey',
#  'Research Analyst, Department of Medicine, Cumming School of Medicine',
#  'Plastic Surgery Clinical Research Co',
#  'Clinical Trial Documentation Assistant',
#  'Regulatory Affairs Associate',
#  'Senior Biostatistician - Pharma / Clinical Trials (Remote, Canada)',
#  'Associate Scientist - Immunology - Project Scientist',
#  'Sr. Scientist, Biologics Product Development',
#  'Scientist/Associate Scientist, Cancer Immunotherapy-T & NK Cell Development',
#  'Quality Control and Quality Assurance Officer',
#  'Physiotherapist - Priority Home Services',
#  'Exceptionally motivated and well qualified Medical Laboratory Assistant/Technician with experience in diverse lab settings. Efficient and pr',
#  'Clinical Trial Administrator',
#  'Research Assistant - Part Time - Immunochemistry',
#  'Scientist or Senior/Principal Scientist, Pkpd/QSP modeling',
#  'Animal Care Assistant',
#  'Supervisor in Toxicology - Sherbrooke Site',
#  'Study Start Up Associate I',
#  'Program Assistant',
#  'Clinical Trial Registries Associate(Allergan)',
#  'Scientist at Zoetis Inc.',
#  'Research Assistant University of New Haven',
#  'Research Nurse / InfirmiÃ¨re de Recherche',
#  'NGS Senior Scientist - Biologics Optimization',
#  'Registered Nurse/Charge Nurse Acute - Hemodialysis',
#  'Biochemistry, chemistry',
#  'Senior Clinical Research Associate, Oncology- New York - Rochester',
#  'Senior Associate/Manager, Regulatory Affairs',
#  'Customer Development Researcher - Internship',
#  'Medical Science Liaison, Rheumatology, Gastroenterology & Immunology- NV-UT-CO, AZ-NM',
#  'Lead Biostatistician-Smith Center',
#  'Senior Biostatistician - Remote',
#  'Senior Information Manager - Regulatory Solutions',
#  'Medical Science Liaison, Breast, Gastrointestinal, & Gynecologic Oncology- NV-UT-CO',
#  'Manager - End User Services - JOHNSON & JOHNSON',
#  'Housekeeping Aide 2',
#  'Clinical research assistant - Medical Arts Health Research Group',
#  'Marketing Specialist, Global Consumer Marketing - Acurian, Inc',
#  'MSL Field Director, Malignant Hematology- West',
#  'Technical director & Clinic Manager - Alta Cardiac CARE',
#  'Synthetic Organic Chemist',
#  'Senior Manager, Medical Affairs / Inflammation (RA)',
#  'Lab Patient Technician - Full Time - Kenora',
#  'Radiology Technologist - Collinsville, IL',
#  'Social Worker (MSW)',
#  'Batcher',
#  'Evidence Sr. Analyst, HEOR (remote position, anywhere in the US or Canada)',
#  'Clinical Trials Administrative Assistant',
#  'Senior Scientist at Pfizer',
#  'Medical Liason',
#  'Specialist - Research-Fixed Term',
#  'Manager, Stroke Clinical Trials Group (SCTG), Clinical Neurosciences, Cumming School of Medicine',
#  'Global Clinical Project Associate 2 - Cambridge, MA',
#  'Director, Global Medical Affairs - JO#2003-5406',
#  'Clinical Research Associate - Topstone Research NKA Veristat',
#  'Principal Investigator, Chemical Development',
#  'Clinical Research Associate - Western Canada - 12 month contract',
#  'Senior Clinical Development Medical Director-Ophthalmology',
#  'Regulatory Manager, Clinical & Labelling',
#  'Postdoctoral Fellow/of Microbiology, Immunology and Biochemistry',
#  'Assistant, Associate or Full Professor - Translational and Clinical Research',
#  'BSN, RN',
#  'Research Assistant - Li Ka Shing Centre',
#  'Registered Nurse RN FT Nights (Victoria North LTACH)',
#  'Consultant, Parexel Consulting',
#  'Animal Research Technician - Animal Services',
#  'Research Technician - Protein Purification',
#  'Knowledge Engineering Specialist',
#  'Medical Science Liaison, Malignant Hematology- Western New England, Upstate NY, Western PA',
#  'Maintenance Assistant',
#  'Quality Control Laboratory Chemist II',
#  'Medical Science Liaison - Ontario West',
#  'MSL Field Director, Neuro-Rare Disease- Central & West',
#  'Research Assistant (RA)',
#  'Home Health Manager (Nurse, PT, OT or SLP)',
#  'Scientist - Oncology, Translational Science, Biomarker Development',
#  'Senior Product Manager, Safety',
#  'Clinical PostDoctoral Fellow, Drexel University WELL Center',
#  'QA Auditor',
#  'Director QA - SIGA Technologies, Inc',
#  'Environmental Tech 1, Environmental Services, FT, 2:30PM-11:00PM',
#  'Medical Science Liaison SMA, Western Canada',
#  'Research Director at Zoetis Inc. (formerly Pfizer Animal Health)',
#  'Cardiology Technologist',
#  'Senior CRA',
#  'Biostatistician - Oakland',
#  'Credentialing Specialist',
#  'Registered Nurse - Clinical Research/Sexual Assault and Domestic Violence Team',
#  'Clinical Trials Monitor Recruiter - BC Cancer Vancouver',
#  'Research Associate / Senior Research Associate',
#  'Laboratory Assistant - Part Time Regular + Float',
#  'Associate Director, Molecular Biology',
#  'Scientist, Clinical Research',
#  'Senior Formulation Scientist',
#  'Clinical Research Nuclear Medicine Fellowship 2019',
#  'Statistical Scientist- 2 Year Contract',
#  'RESEARCH ASSOCIATE, Gastroenterology, Hepatology',
#  'CLINICAL SCIENTIST',
#  'Clinical Operations Manager',
#  'LICENSED PRACTICAL NURSE- CANTON',
#  'Medical Science Liaison, Lytics - West',
#  'Clinical Research Associates',
#  'Senior Research Biostatistician',
#  'Clinical Research Start-Up Trial Manager (1 Year Contract)',
#  'RN - 3W & Float',
#  'Clinical research associate',
#  'Research Assistant(Temp/Part-Time)',
#  'Oncology Infusion RN',
#  'Director, Business Development',
#  'Quality Control & Assurance Specialist',
#  'Registered practical nurse looking for full time position',
#  'Fredericton Registered Nurse Class A (RNCA) PCN 1154748',
#  'Clinical Research Coordintor II Cardiovascular RN FT Days',
#  "Registered Nurse (Physician's Office)",
#  'LPN//EMR',
#  'Pharmacovigilance / Drug Safety / Clinical Research',
#  'Part Time Laboratory Assistant',
#  'Clinical Research Associate - Maritimes - 12 month contract',
#  'Lead CRA - Synergy Research',
#  'Assistant Professor/Clinical',
#  'Project Associate - Clinical Trials',
#  'Budget Analyst/Financial Management',
#  'Senior Scientist -Analytical Services (Remote Contractor) - Capzer Pharmaceuticals, Inc',
#  'R&D Scientist, Cellular Manufacturing',
#  'Senior Principal Scientist, Immune Modulation',
#  'Clinical Product Support Specialist, Associate (PharmD, RN, NP, PA - Remote or NYC)',
#  'Statistical Research Assistant',
#  'Infection Control Professional (N4) - Repost',
#  'Bilingual Clinical Research Associate',
#  'Clinical Trial Specialist, Clinical Operations',
#  'Director, Field Medical',
#  'Clin Trials Rsrch Associate',
#  'Registered Nurse - 3 Chi',
#  'Clinical Research Assistant- Infectious Disease- Research Detroit location- Full time/w benefits',
#  'Infection Control Nurse',
#  'Principle Investigator - Clinical Trials',
#  'Technologist - Downstream cP Team 3',
#  'Clinical Associate Program Manager',
#  'Senior Scientist â€“ Antibody Assessment',
#  'External Scientific Research Manager, Oncology',
#  'clinical Research Assistant and conducting phase II clinical',
#  'Scientist II',
#  'Registered Nurse - Mars, PA',
#  'Infection Control Coordinator - Casual',
#  'Senior Clinical Trial Manager (Sr. Clinical Lead)',
#  'Medical Science Liaison - Medical Affairs',
#  'Medical Science Liaison, Malignant Hematology- Seattle & AK, Western OR, Eastern WA/OR-ID-MT',
#  'Associate Scientist production, LBA',
#  'Teaching Assistant (TA) in clinical research',
#  'Senior Associate Director/Director, Pharmacometrics',
#  'RESEARCH ASST PROFESSOR',
#  'Member - Online Working Group',
#  'RN - ED',
#  'Research Coordinator - BC Cancer',
#  'Faculty Member, Pathogen-Associated Malignancies',
#  'General Duty Nuclear Med Technologist - Repost',
#  'Sr Territory Business Manager - CV Specialty',
#  'GCP QA Director/Senior Director',
#  'Publication Lead, Rare Genetic Diseases',
#  'Senior SAS Programmer',
#  'Senior/Principal Research Associate',
#  'QA Manager',
#  'Registered Nurse (RN) Casual',
#  'Assistant Professor- Fixed Term at Michigan State University',
#  'Product Owner, Translational Genomics',
#  'Senior Research Scientist - Biology',
#  'EMT Paramedic Union EMS',
#  'Quality assurance Technician',
#  'Associate Research Investigator, Immunoassay',
#  'Lab Patient Technician (Training Available)- Part Time Regular',
#  'Medical Science Liaison, Breast, Gastrointestinal, & Gynecologic Oncology- MS-LA, AL-Panhandle, TN',
#  'Clinical Research Associate I - Oncology (Montreal)',
#  'Supply Chain Manager',
#  'Medical Science Liaison, Benign Hem/Sickle Cell - Detroit - Remote',
#  'Biomedical Scientist',
#  'Clinical Supply Manager',
#  'Administrative assistant/Staffing Coordinator Central Supply/ CNA Supervisor',
#  'Manager, Strategic Pricing',
#  'Project Scientist - Immunology and Cancer - Yu Lab',
#  'Translational Renal Biologist',
#  'FSP - Senior Clinical Research Associate (Oncology / Toronto, Vancouver, Winnipeg)',
#  'Intellectual Property Research Scientist',
#  'Registered Nurse-Extended Class',
#  'Sr. Research Associate / Associate Scientist - Immunology',
#  'Emergency Department Nurse',
#  'Pan Tumor/Immuno-Oncology Medical Science Liaison/Sr. MSL- Northern CA/Reno',
#  'Contract Senior Clinical Research Associate / CRA II',
#  'Manager, Medical Science Liaison, Rheumatology',
#  'Sequencing and Molecular Biology Technologist',
#  'Manager or Senior Manager, Clinical Operations',
#  'Validation Associate',
#  'Associate Director, Toxicology and Biodistribution',
#  'Laboratory Assistant (Aliquoting)',
#  'Work in taproom, ServSafe Certified, Cicerone Beer Server Certified - Badger Hill Brewing Company',
#  "REGISTERED NURSE - MEDICAL/SURGICAL, ST. PAUL'S HOSPITAL",
#  'Postdoctoral Scientist at Centre for Addiction and Mental Health',
#  'Retiring Registered Nurse with over 30 years in creating genuine moments of connections with people',
#  'Manager, Customer Service',
#  'An enthusiastic and dedicated medical professional with diverse experience in fast paced clinical, operational and administrative medical pr',
#  'Independent Scientist NEW',
#  'Research Assistant I',
#  'Agent de Liaison, Sciences MÃ©dicales/Medical Science Liaison - Quebec',
#  'Cardiovascular Technologist, Reg Elig',
#  'QA Associate - Eurofins BioPharma',
#  'Postdoctoral Research Fellow - Antibody Engineering',
#  'Registered Nurse - Infectious Disease Programs',
#  'Director Regional Clinical Trial Operations',
#  'Clinical Science Liaison',
#  'Clinical Scientist/Senior Clinical Scientist',
#  'Associate Scientist- Immuno-Oncology',
#  'Asst Professor (grant ten-trk)',
#  'Clinical Research Coordinator II - Hospital Medicine (C)',
#  'Senior Manager, Biostatistics',
#  'Director of Biostatistics - Niche BioPharma - Great benefits!',
#  'Director, Alliance Management',
#  'Paediatrician - Division of Infectious Diseases - 11689',
#  'Lab Assistant (Non-Technical)',
#  'Lab Patient Technician- Temporary Full Time (Day)',
#  'Lab Patient Technician- Part Time Regular (Day)',
#  'In vivo Scientist/Pharmacologist',
#  'Formulation Compounding Chemist - Fresenius Kabi USA LLC',
#  'Clinical Research Laboratory Manager',
#  'tattoo artist',
#  'Certified Nursing Assistant (CNA) 7-3 & 3-11',
#  'Medical Writing Publication Specialist',
#  'Co-Development Quality Assurance at Pfizer (Michigan)',
#  'Global Study Leader - Oncology',
#  'Medical Science Liaison- Denver, CO',
#  'Senior Manager, Regulatory Affairs, Global Labeling',
#  'MDS Coordinator (LVN)',
#  'Associate Scientist - Project Scientist - Immunochemistry',
#  'Scientist/Sr. Scientist, In Vivo/Phage Antibody Discovery - Protein Sciences',
#  'Regulatory Affairs, MBA (Marketing), B. Pharm, PG Dip. Clinical Research',
#  'Cleaner',
#  'Senior Clinical Trial Associate',
#  'Senior Biostatistician',
#  'Research Associate, Psychiatry, Cumming School of Medicine',
#  'Buyer',
#  'LICENSED PRATICAL NURSE - Medication Administration',
#  'Manufacturing Associate II',
#  'ORISE Fellow to Dr. Dongyi - U.S. Food and Drug Administration, CDRH, Division of Epidemiology',
#  'Engineering and Production Technologist',
#  'Laboratory Assistant - Part Time Regular Float - Parksville, Qualicum, Port Alberni',
#  'Clinical Research Associate (Bilingual)',
#  'Regional or Sr. Regional Medical Liaison, Cardiovascular (Western Canada)',
#  'Associate, Drug Information',
#  'Sr Clinical Trial Manager - Clinical Operations x 2 positions',
#  'Lab Patient Technician - SEIU Temporary Part Time',
#  'Associate/Scientist, Oncology BioMarker Development (Hematology)',
#  'Senior Scientist I',
#  'Orthopedic Technician',
#  'Clinical Research Associate, Quebec, 12 Month Contract',
#  'Laboratory Aid',
#  'Clinical Research Associate 1-Home Based - Quebec - Oncology/Diabetes',
#  'Asst. Professor (Retired) @ WMU; Former Sr. Scientist-Pharmacia/Pfizer (Retired)',
#  'Research Assistant  - Centre for Addiction and Mental Health (CAMH)',
#  'Clinical Research Associate II & III - Oncology (Remote)',
#  'Sr Scientist, Clinical Research',
#  'Assistant Professor - (Research Educator)',
#  'Biomedical engineering scientist',
#  'Assistant, Associate or Full Professor',
#  'OPSEU BA Lab Patient Technician- Part Time Regular',
#  'Peter Ellefson',
#  'Larry McBride',
#  'Analyst, bioanalysis',
#  'Senior Global Study Leader, Biopharmaceuticals',
#  'Moncton Research Assistant (N-B) PCN 1002931',
#  'Manager, Clinical Trial Associates (CTAs)',
#  'Laboratory Assistant-Temp- Part Time Regular Float- Vancouver 1',
#  'Associate Scientist (Contract Services)',
#  'LPN - Physician office nurse',
#  'Lab Patient Technician Full-Time (3984 Albert)- Regina, SK',
#  'Clinical Research Assistant, Sunnybrook Research Institute',
#  'Medical Science Liaison, Rheumatology, Gastroenterology & Immunology- DC-Baltimore, VA, KY-WV, TN',
#  'Oncology Specialty Consultant',
#  'Director, Field Strategy & Communications',
#  'Analyst 1',
#  'Medical Science Liaison- Northeast',
#  'Clinical Lead - (Day & Night)',
#  'Associate Director, Pharmacometrics',
#  'Medical Science Liaison / Respiratory Franchise - Ontario',
#  'Consultant Specialists, Inc. (CSI): Risk manager',
#  'Lab Patient Technician- - SEIU',
#  'Research Coordinator (Permanent Full Time), Research Services',
#  'Senior Scientist - Pharmacology',
#  'Staff Therapist - Physiotherapy',
#  'Laboratory Technician - Fairlife Inc',
#  'Technical Lead - HCL America Inc.',
#  'Clinical Site Manager / CRA',
#  'Clinical Trials Researcher and Clinician',
#  "Research Associate - Children's Hospital Research Institute of Manitoba",
#  'Ph.D. IMMUNOLOGIST',
#  'FSP - Manager, Clinical Research (CRM)',
#  'Research Coordinator I Trauma & Neurosurgery Resea',
#  'REGISTERED PRACTICAL NURSE - Bayshore',
#  'Advanced Technician',
#  'Research Assistant, Office of Performance Assessment and Clinical Effectiveness',
#  'Epidemiology Supervisor',
#  'Production Supervisor',
#  'Gastroenterology National Medical Science Liaison - East',
#  'Chief Marketing Officer/Association Director',
#  'Project Coordinator',
#  'Director of Business Development',
#  'Sr Manager,Mfg & Mfg Proc Mgmt',
#  'Clinical Business Analyst',
#  'Research Lab Analyst - Lambda Therapeutic Research',
#  'Physician Assistant - UMPGH',
#  'Registered Nurse, RN - Full Time Eve/Nights',
#  'Scientist - LBA Development',
#  'Lawson, Research Associate - Department of Cardiology Research',
#  'Patient Care Specialist Part-Time - Family Care of Culpeper',
#  'Support Technician Clinical Laboratories (evening shift)',
#  'Grants Manager & Research Administrator - Sunnybrook Research Institute, Sunnybrook Health Science Center',
#  'Reference technologist',
#  'Mobile Laboratory Patient Technician (Regular Part Time)',
#  'Research Manager, ORS',
#  'Laboratory Assistant (Non-Union) Temporary Part Time Regular - Newton PSC',
#  'Psychologist',
#  'Registered Nurse - Research',
#  'Clinical Subjects Associate - University of Michigan',
#  'Junior Statistical Programmer',
#  'Principal Statistician - Payer Evidence',
#  'Marketing Director â€“ Internal Medicine / Directeur du marketing â€“ MÃ©decine Interne',
#  'Research Software Engineer (Web Development)',
#  'Translating Research in Elder Care (TREC)',
#  'Laboratory Assistant Part Time Regular - Kerrisdale PSC & Victoria Drive PSC',
#  'Registered Nurse, Infectious Disease Programs',
#  'Senior Clinical Trial Manager',
#  'Research Technician -  STRUCTURAL GENOMICS CONSORTIUM',
#  'Lab Technician and Research Coordinator - Mount Sinai Hospital Research Institute',
#  'Quality Support Technician â€“ Deeley Research Centre (Victora), BC Cancer Research',
#  'Senior Scientist, Computational Structural Biologist',
#  'Necropsy Technician 2',
#  'Medical Science Liaison, Ophthalmology- NV-UT-CO, Eastern WA/OR-ID-MT',
#  'Director, Business Development, Non Clinical, Toxicology Services-MA',
#  'Clinical Trial Support Associate',
#  'Medical Laboratory Assistant',
#  'Virtual Rural Generalist Service',
#  'Physiotherapist-Repost',
#  'Lead Biostatistician',
#  'Secretary and Dispatch - HALL COUNTY ROAD MAINTENANCE',
#  'Camp Iroquois Arts & Crafts Director',
#  'Laboratory Assistant- Casual, Kamloops, BC',
#  'Registered Practical Nurse (Casual)',
#  'Medical Science Liaison â€“ Immuno-Oncology',
#  'Pharmacy Tech',
#  'Laboratory Assistant - Part Time Regular - North Road PSC',
#  'Adherence & Community Engagement (ACE) Team Licensed Practical Nurse (LPN)',
#  'REGISTERED PRACTICAL NURSE',
#  'Scientist I/II, Protein Science',
#  'MSc Researcher',
#  'Executive Director, R&D Quality & Compliance',
#  'FSP - Senior Clinical Research Associate (Oncology, Montreal)',
#  'Certified Nursing Assistants (Cna)',
#  'Bilingual Clinical Study Associate - GlaxoSmithKline',
#  'Manager, Clinical Operations - line management position',
#  'M.D. at University of Michigan',
#  'Research Fellow/Director, Quantitative Clinical Pharmacology',
#  'Assistant Professor (tenure-track)',
#  'Scientist- Assay Development',
#  'Occupational Therapist - Acute Care - Repost',
#  'Visiting Scientist - Dept. Clinical Pharmacology',
#  'Sr Clinical Research Associate - Oncology - Vancouver',
#  'Clinical Assistant - Inflamax Research',
#  'Medical Laboratory Assistant (Phlebotomy)',
#  'Regulatory Specialist - Baylor University Medical Center',
#  'RN program Planner for Adult Day Program - Northwood',
#  'Professor - Internal Medicine Kateb Medical School',
#  'experienced pharmaceutical and clinical research professional',
#  'QA Manager - Avomeen Analytical Laboratories',
#  'Clinical Trial Manager at Precision Oncology .',
#  'Assistant Research',
#  'Senior Scientist - Biomolecular Sciences & Chemical Sciences, GlaxoSmithKline, Inc',
#  'Medical Science Liaison, Respiratory- DC-Baltimore, VA',
#  'Research Associate I',
#  'Senior Technical Manager (ref.#1550)',
#  'Sr Manager, Market Access & Reimbursement Strategy â€“ Advanced Technologies',
#  'Bioanalytical Chemistry Lab Assistant 1',
#  'Bilingual Medical Science Liaison, 1 Year Contact',
#  'Junior Research Coordinator / Coordinateur de recherche junior',
#  'Lab Patient Technician - Full-Time - Toronto',
#  'Senior QA Analyst - Allianz Insurance',
#  'BioStatistician - Blue Cross Blue Shield of Michigan',
#  'Director, Clinical Pharmacology and Pharmacometrics',
#  'Medical Office Assistant',
#  'COVID-19 Nurse - Inventory',
#  'Research Associate, Antibody Discovery, Purification, and Characteriza',
#  'Senior Counsel/Senior Counsel Specialist AGC - Corporate and Transactional Law Group',
#  'Research Technician: Antibody Development/Purification',
#  'Senior Director, Clinical Project Management (Global Portfolio Head, Rare Disease)',
#  'Medical Science Liaison MS (QC/Atl)',
#  'Supervising Physician Specialist - Director PHEPR',
#  'Regional Manager Clinical Affairs',
#  'RRT / CRT - Registered Respiratory Therapist - ProMedica Coldwater Regional Hospital - Full Time - Nights',
#  'Manager - Associate Director Biostatistics (can be partially remote)',
#  'Sleep Research Engineer - Wayne State University School of Medicine',
#  'Medical Science Liaison - Hematology (Western Canada)',
#  "Research Volunteer - St. Michael's Hospital",
#  'Manager, Clinical Systems (IRT)- CDM Systems Manager',
#  'Lab Patient Technician - Thornhill - Part',
#  'Phlebotomy/Laboratory Technician',
#  'Clinical Research Medical Director - Oncology (Blincyto)',
#  'Clinical Research Analyst',
#  'Medical Science Liaison - Oncology/ Agent de Liaison, Sciences MÃ©dicales - oncologie (Quebec)',
#  'Scientist- Molecular Biologist',
#  'Scientist',
#  'Associate Director Statistical Programmer',
#  'Registered Nurse or Licensed Practical Nurse - Pennsville, NJ',
#  'Administrative Research Coordinator - Winship Cancer Institute- Emory University',
#  'Medical Scientific Liaison - Ophthalmology, Quebec',
#  'Staff Therapist - Occupational Therapy',
#  'Manager Quality Assurance / Chef, Assurance QualitÃ©',
#  'VP, Peptide Formulation',
#  'Clinical Biomarker Operations Manager',
#  'Research Nurse II',
#  'Medical Science Liaision - Ontario East',
#  'Senior Research Officer',
#  'CARDIAC RESEARCH MANAGER',
#  'Lab Patient Technician SEIU - Part Time',
#  'Medical Science Liaison, Myeloid - Northern California',
#  'Curriculum Developer (Remote)',
#  'R&D Engineer in Single Cell Genomics Platform',
#  'Laboratory Assistant II',
#  'Assistant/Associate Professor of Clinical Neurology-CHLA',
#  'Research Intern',
#  'Clinical Trials Kinesiologist',
#  'MEDICAL LABORATORY ASSISTANT - DYNALIFEDX',
#  'Clinical Research Associate II, Abbott Point of Care (Ottawa)',
#  'Assistant Manager, Research',
#  'Senior Clinical Research Coordinator - Medicine Institute',
#  'Clinical Research Associate II, Immunotherpay',
#  'LPN Charge Nurse - CENTENNIAL HEALTHCARE SERVICES',
#  'Research Assistant - Bioanalytical',
#  'Pathology Assistant',
#  'Senior Manager, Commercial Excellence - Internal Medicine / Gestionnaire en chef â€“ Excellence commerciale â€“ MÃ©dicine Interne',
#  'Biological Technologist',
#  'Medical Science Liaison (MSL) â€“ Western Canada â€“ Lung Cancer',
#  'Material Handler - Shipping and Receiving and Inventory Control',
#  'Academic Urologist',
#  'Manager, Clinical Research',
#  'Team Lead, Quality Control (QC) Biotechnology',
#  'Clinical Resource - Respiratory Therapy',
#  'RRT / Registered Respiratory Therapist - Respiratory Therapy - Part Time - Evenings',
#  'Regional Medical Liaison',
#  'Swetha Rangam',
#  'Research Technician Assistant',
#  'ARNP',
#  'Clinical Research Coordinator I Oncology',
#  'Principal Clinical Dictionary Analyst',
#  'Senior Principal Biostatistician',
#  'AssociÃ©(e) de recherche clinique / Clinical Research Associate',
#  'Clinical Research Physician, Respiratory',
#  'Clinical Data CoordinatorÂ\xa0',
#  'CQA Program Manager',
#  'Lab Patient Technician - Part-Time Regular',
#  'Study Management Senior Manager',
#  'Field Application Scientist',
#  'Clinical Research Coordinator I - Pediatrics Hematology/Oncology',
#  'License Practical Nurse',
#  'Deputy Manager - (Day & Night)',
#  'Pediatric Infectious Disease',
#  'Senior Research Coordinator',
#  'Principal Scientist, Computational Chemistry',
#  'Scientist (Process Chemistry)',
#  'Assistant Professor of Clinical - Pediatrics (Pediatric Infectious Diseases, Allergy, and Immunology)',
#  'Scientist -Ligand Binding',
#  'Socio-Behavioral Scientist',
#  'Clinical Development Consultant, Site Engagement - Ontario',
#  'Temporary Clinical Financial Analyst',
#  'Research Coordinator - Cardiology',
#  'Charge X-Ray Technologist - Child Health - Repost',
#  'Quality Scientist I (Full-Time Employee)',
#  'BioAnalytical Manager III',
#  'Clinical Associate',
#  'Clinical Research Coordinator I - INFLAMAX RESEARCH',
#  'RN - CENTRAL RESEARCH',
#  'Quality Coordinator BMTÂ\xa0',
#  'Research Asst/Tech 2 - Gastroenterology',
#  'Nurse Practitioner Program Student, Neonatal Intensive Care Unit',
#  'Territory Manager Eastern Canada',
#  'Senior Medical Writer',
#  'Synthetic Organic Chemist (Production)',
#  'Business Performance Senior Manager â€“ Research and Development',
#  'Quality Assurance & Compliance Specialist',
#  'Charge Nuclear Medicine Technologist - Technical Instructor',
#  'Clinical Research Associate II or III-Diabetes/Oncology-Montreal',
#  'Senior Manager Process Development',
#  'Medical Science Liaison, Malignant Hematology- MS-LA, AL-Panhandle, TN',
#  'Quality Assurance Associate - 15 month contract',
#  'Manager, Program Management',
#  'Theodore Kiliszewski',
#  'Certifying Scientist',
#  'Medical Director',
#  'Registered Nurse Research Coordinator, Research Services',
#  'Clinical Trials Associate (CTA)',
#  'Clinical Research Associate II',
#  'Medical laboratory technician',
#  'Clinical Research Associate II (Unblinded monitoring, Montreal)',
#  'Executive Director, Epidemiology Tas',
#  'Physical Therapist Altus Outpatient PT Clinic (FT)',
#  'Head, Director of Strategy and Business Operations â€” USMA Field Medical',
#  'CLINICAL TRIALS SPECIALIST',
#  'Radiologic Technologist - North Huntingdon, PA',
#  'Field Applications Scientist',
#  'Associate Director, CMC',
#  'Mass Cytometry Technologist - The Hospital for Sick Children',
#  'GVP Inspection Readiness Specialist',
#  'Medical Science Liaison (MSL) - Hepatology - JO#2003-5403',
#  'Medical Science Liaison, Lytics - Northeast',
#  'Director, Formulations',
#  'Clinical Research Associate - Bilingual',
#  "Radiologic Technologist - O'Fallen, IL",
#  'Clinical Pharmacy Specialist',
#  'Bilingual Clinical Research Associate (II/Sr) - Up to 10K Sign On!!!',
#  'Medical Science Liaison - Cardio/Renal/Metabolic (Diabetes) - Eastern Ontario & Quebec',
#  'Lab Technologist',
#  'Research Associate  - Tanz CRND in the University of Toronto',
#  'Scientist (ELISA Development)',
#  'Scientist - Tissue Regeneration Therapeutics (TRT)',
#  'CPAP Specialist',
#  'Scientist, Antibody Engineering',
#  'Scientist, Cognitive NeurodegenerationÂ\xa0',
#  'Senior Site Manager (Senior Clinical Research Associate)-Western Canada',
#  'Clinical Trial Manager - San Diego, CA',
#  'APP - Pediatric Genetics',
#  'Senior Quantitative Epidemiologist',
#  'Project Manager - Clinical Trials',
#  'CNA - Part-Time',
#  'Registered Nurse - Part Time or Full Time',
#  'Associate Professor/Clinical',
#  'Nursing Assistant (Certified)',
#  'Lab Supervisor, Histology, Full-Time',
#  'DH Laboratory Assistant - Monsanto Canada',
#  'REGISTERED NURSE II',
#  'Associate Scientist - Immunotherapy',
#  'Clinical Medical Pharmacist',
#  'Clinical Support Assistant, 5D Progressive Care, Part Time, 7a-7p, Sat/Sun',
#  'Senior Regulatory Affairs Consultant',
#  'Senior Conservator',
#  'Research Assistant - Chemistry Department, Western Michigan University',
#  'Oncology Clinical Research Manager',
#  'Clinical Research Associate R & D. Ontario.Contract 12 months and more. Posted until September 5',
#  'Antibody Engineering Leader - South Bay Area, CA',
#  'SEND Analyst 1 1',
#  'GMP Quality Assurance Manager',
#  'Production Operator',
#  'Director of Clinical Biomarker, Oncology Synthetic Lethality',
#  'Future Opportunities - Laboratory Project Services Manager',
#  'Registered Practical Nurse (RPN)',
#  'Senior Director, Head of Regulatory Affairs',
#  'Infection Control Coordinator - Full-Time',
#  'Registered Nurse BScN',
#  'Clinical Research Project Manager I - Hepatology and Nutrition',
#  'QA Intern - Cetaris',
#  'Associate Medical Director, Physician Development Program - Dermatology',
#  'Supervisory Radiographer- Mammography',
#  'Material Control Associate',
#  'Statistical Scientist-Personalized Healthcare, Medical Affairs',
#  'LPN LIAT OHN',
#  'Associate VP Sales, Narsoplimab HSCT-TMA',
#  'Research Assistant 1',
#  'Associate Scientist (Cell Metabolism)',
#  'Regional Medical Advisor, Quebec/Atlantic - Hematology/ Conseiller MÃ©dical RÃ©gional, QuÃ©bec/Atlantiqueâ€“ HÃ©matologie',
#  'Manager, Data Management',
#  'Scientist II Stability',
#  'Scientific Advisor, MF & AML',
#  'Senior Scientist at Zoetis Inc.',
#  'sr scientist at Wacker Chemie AG',
#  'Clinical Research Medical Director Transplant - Remote',
#  'Infectious Diseases Investigator, Tenure Track with Rank DOQ, Internal Medicine Dept.',
#  'Senior Research Associate',
#  'Medical researcher',
#  'Senior Director of Alliance Management and Operations',
#  'Exec Director Medical Writing',
#  'Clinical Research Manager (Quebec - sponsor focused)',
#  'Social Worker (BSW) - Repost',
#  'Junior Research Coordinator / Coordonateur de recherche junior',
#  'Molecular Biologist / Biological Researcher',
#  'Sr. CDMA Project Lead - Phacoemulsification Equipment',
#  'Product Director, Virtual Trials',
#  'Associate Director, Medical Writing',
#  'Infection Control Registered Nurse',
#  'OpÃ©rateur',
#  'Synthetic Organic Chemistry Intern (Forensic Production)',
#  'Community and Clinic Suport Worker- Repost',
#  'Laboratory Assistant - ALS Environmental Laboratory',
#  'Manager, cGMP Quality Systems (Drug Product)',
#  'Postdoctoral Fellow (Vijayanand)',
#  'Supv V Medical Technologist',
#  'Community Stroke Care Case Coordinator',
#  'Research Technician - Safety Pharmacology',
#  'Junior Biostatistican',
#  'Occupational Therapist',
#  'Clinical Research Recruiter',
#  'Genetics Lab Assistant',
#  'Research Clerk',
#  'Medical Coder CCS-P certified',
#  'Medical Director-Oncology Clinical Development - dostarlimab-',
#  'Mixer',
#  'Cardiovascular PerfusionistÂ\xa0',
#  'Global Study Leader - Biopharmaceuticals - Respiratory',
#  'Sr. Scientist, Biology',
#  'Formulation Research Associate (Preclinical and Clinical)',
#  'Laboratory Assistant (Non Union) - Part Time Regular Float',
#  'Senior Principal/Principal Biostatistician',
#  'Intern Opportunities - Summer',
#  'Clinical Research Coordinator/ Laboratory Technician',
#  'Charles River is a leading global contract research organization that helps clients accelerate their research and drug development efforts. ',
#  "Administrative Assistant II - Nationwide Children's Hospital",
#  'Paramedic and Chief - Mowbray Volunteer Fire Department',
#  'Detail-oriented clinical research coordinator with clinical, clairical and electronic medical records experience',
#  'Clinical Scientist Early Clinical Development',
#  'Project Leader SAS, Clinical Data Management',
#  'Research Associate - Biotherapeutic Discovery',
#  'Director, Clinical Pharmacokinetics',
#  'Clinical Trials Center Manager',
#  'Research Associate-RI',
#  'Clinical Nurse Supervisor - Kentfield Rehabilitation and Specialty Hospital/LTAC',
#  'Principal Quality Lead',
#  'DIRECTOR,PROGRAM AND PORTFOLIO MANAGEMENT',
#  'CLIA Director over Drug of Abuse Screening - Better Health and Wellness, LLC',
#  'Band 6 Research Nurse',
#  'Sr Research Assoc',
#  'CLINICAL TRIAL DOCUMENTATION ASSISTANT - Access Pharma Group',
#  'Manager, Biostatistics, Medical Affairs',
#  'Site Manager III - Early Development and Clinical Pharmacology (Oncology)',
#  'Group Leader â€“Cancer Biology, Translational Pharmacology',
#  'Chef Principal, Affaires Gouvernementales',
#  'Postdoc Fellow Machine Learning for Biomolecule Engineering',
#  'Business Development Analyst',
#  'Pharmaceutical Manufacturing & Packaging Operators (Level 2 and 3)',
#  'Pharmacovigilance -Quality Control Specialist (6 Month Contract)',
#  'Associate Software Engineer',
#  'Polysomnographic Technologist',
#  'Research Technician - Neurobehavioral Sciences',
#  'Angela Owens',
#  'Senior Manager, Quality Assurance - Astellas Pharma Canada, Inc',
#  'Independent Scientist',
#  'Senior Clinical Laboratory Technologist - Strata Oncology',
#  'Research Assistant - Test Material Control - DMPK',
#  'Director, Program Management New Market Development',
#  'Oncology Specialty Sales Consultant - Prostate Franchise - Los Angeles East, CA',
#  'Registered Nurse - Northface Surgery',
#  'Patient Care Specialist Part-TIme (20+) - Culpeper Family Practice',
#  'Medical Science Liaison, Breast, Gastrointestinal, & Gynecologic Oncology- ND-MN, SD-NE-IA',
#  'Research Coordinator - St. Joseph Health Care',
#  'Senior Director, Clinical Development Sciences',
#  'Medical Science Liaison, Lung, Genitourinary, & Dermatologic Oncology- Western New England, Upstate NY, Western PA',
#  'Biostatistician,Sr',
#  'Cook - Atrium Health Kings Mountain',
#  'Gestionnaire de recherche clinique / Clinical Project Manager',
#  'Scientist IV, Hiregenics providing services for Johnson and Johnson',
#  'Associate Research Scientist II',
#  'Scientist Formulation Development - Toronto',
#  'Registered Respiratory Therapist III',
#  'Registered Nurse RN',
#  'CNA - Per Diem',
#  'Scientific Technician',
#  'Graduate Statistician',
#  'QC Data Reviewer',
#  'Screener',
#  'Senior Project Manager - Clinical Trial Management (CTM)',
#  'Research Assistant Professor at University of Michigan Medical School',
#  'MSL Field Director, Lung, Genitourinary, & Dermatologic Oncology - Southeast & Central',
#  'Research Technician/Assistant',
#  'Sr CRA (Western Canada)',
#  'Richard Millering',
#  'QC Biochemistry Technologist Level 2 (AFTERNOON SHIFT)',
#  'Life Science Research Professional 1',
#  'FSP - Bilingual Oncology Clinical Research Manager (Project Manager',
#  'Toxicology Study Director',
#  'Research Ethics Coordinator-Contract',
#  'Clinical Supervisor- RN',
#  'Lab Patient Technician - Temporary Part Time Regular (18 Months)',
#  'Clinical Research Data Entry',
#  'Research Assistant - McGill University',
#  'Senior Medical Director / Medical Director - REMOTE, US',
#  'Associate Medical Affairs Operations Director',
#  'RN- Inpatient Renal/Dialysis- Unit Pool (Wage/PRN)',
#  'Research Associate, Orthopaedic Trauma, Department of Surgery, Cumming School of Medicine',
#  'VP of Data Science',
#  'Sr. Principal Scientist/Principal Scientist - Translational Autoimmunity',
#  'Clinical Study Manager',
#  'Senior Clinical Research Associate (CRA)',
#  'Medical Scientist',
#  'Senior Manager, Statistical Programming',
#  "Research Assoc I/II, Assay Dev't, PD Analytics Req# 2020",
#  'OFFICE OF HUMAN RESEARCH PARTICIPANT PROTECTION (HRPP) & INSTITUTIONAL REVIEW BOARD (IRB) -DIRECTOR - University of Oklahoma',
#  'Principal Scientist, Early Development Predictive Sciences',
#  'Copywriter, Life Sciences',
#  'Department of Oncology, Medical Oncologist',
#  'Staff RN - St. John Providence Health System',
#  'Director (Pharmacovigilance)',
#  'ACCOUNTS PAYABLE SPECIALIST - OCTANE FITNESS - A Division of Nautilus, INC',
#  'Project Assistant - Client Dedicated - Mississauga, Canada',
#  'Senior Clinical Research Associate (Canada - Oncology, ID, Allergy)',
#  'Director, Student Health Center',
#  'Clinical research assistant',
#  'RESEARCH ASSISTANT,CLINICAL RESEARCH COORDINATOR',
#  'Consultant- Project manager',
#  'Territory Manager',
#  'Regulatory Affairs I  Biotechnologist',
#  'Laboratory Assistant, Casual - Cowichan, BC',
#  'CRC',
#  'Learning Lab Specialist',
#  'Manager ASR Medical Writer',
#  'Gastroenterology Research Coordinator',
#  'Quality Control Technician',
#  'Band 6 Clinical Research Nurse',
#  'Pharmacovigilance Associate',
#  'Technologist MWS',
#  'Health Promotion Harm Reduction Worker',
#  'Clinical Operations Intern - Masters/PHD (May 2020 4 Months)',
#  'Medical Lab Assistant (Phlebotomy)',
#  'Analyst in Genetic Toxicology',
#  'Research Associate - Drug Discovery Platform - Research Institute of the MUHC (Glen Site)',
#  'RCM (Resident Care Manager)',
#  'Professor of Microbiology',
#  'Medical Science Liaison - Hematology Quebec/Atlantic Canada (contract)',
#  'LVN PATIENT CARE SPECIALIST - SPRING FERTILITY',
#  'Administrative Assistant',
#  'Clinical Research Coordinator I - Jefferson Clinical Research Institute',
#  'CNA - Certified Nursing Assistant - Part Time & Full Time',
#  'L.I.T Program Director',
#  'Registered Practical Nurse - West Park Hospital',
#  'Worldwide Health Economics and Outcomes Research',
#  'Respiratory Therapist III - Pulmonary Diagnostics Supervisor',
#  'Scientist, Biology',
#  'ASSAY DEVELOPMENT TECHNOLOGIST',
#  'RMM-BJ LC',
#  'Research Technician - General Toxicology (Small Animal)',
#  'Sr. Quality Assurance Specialist',
#  'Senior to Associate Director, Biostatistics',
#  'Senior Statistical Programmer - Oncology Trials / Pharma (Remote, Canada)',
#  'Staff RN',
#  'Associate Scientist, Antibody Generation',
#  'Junior Research Coordinator | Coordonnateur de rechercher junior',
#  'Research Contracts Associate',
#  'Research Coordinator - Epidemiology and Population Health',
#  'Principal Research Associate, Platform Analytics',
#  'Senior Clinical Scientist, Early Development',
#  'Regulatory Analyst - Pharmaceutical Industry',
#  'My Profile',
#  'Scientist I Analytical Operations',
#  'Clinical Trial Safety Associate',
#  'Medical Scientific Liaison, Biopharmaceuticals - Quebec & Atlantic',
#  'Casual Administrative Officer (Level 2)',
#  'Sr. Executive Associate to the CMO, Global Drug Development',
#  'Manager, R&D Quality',
#  'Research Scientist - Cellular and Molecular Biology',
#  'Associate Director/Director, Regulatory Affairs',
#  'Kevin Adams',
#  'Scientist, Data Science',
#  'Associate Professor (WOT) or Full Professor (WOT), Department of Pediatrics, The Center for Global Infectious Disease Research (CGIDR)',
#  'Licensed Practical Nurse / Medical Technologist',
#  'Oncology Congress Lead Director (Global Marketing Director)',
#  'Manager, Environmental Health and Infectious',
#  'Associate Director of BioStatistics',
#  'Certified Dietary Manager/Culinary Director',
#  'Laboratory Assistant - Part Time Regular Float',
#  'Clinical Research Coordinator II - Fetal Diagnosis & Treatment',
#  'Research Assistant II - Preclinical Study Technician, BC Cancer Victoria',
#  'RD Laboratory Technologist - Biosciences',
#  'Research Associate - Cellular and Molecular Biology',
#  'â€‹Scientist, Analytical Sciences Biochemistry',
#  'GMA Oncology Franchise Medical Director- NIRAPARIB (SYNTHETIC LETHALITY)',
#  'Major Account Manager',
#  'Laboratory Assistant - Part Time Regular - Cedar Hill PSC - Victoria, BC',
#  'Medical Science Liaison at Flexion Therapeutics',
#  'Research Administrator, Community Health Sciences',
#  'Orthotics Resident - Orthotics',
#  'Primary Care RN - GShare Primary Care RN - G',
#  'Breast Oncologist- Tufts Medical Center in Boston, Massachusetts',
#  'Clinical Research Associate III-Oncology (Calgary or Edmonton)',
#  'Psychiatrist (Inpatient), Assistant Professor of Clinical',
#  'Clinical Research Associate - Hematology Disease Site Group',
#  'Research Associate/Quality Analyst',
#  'Cardiovascular Metabolic Disease Medical Science Liaison/Sr. MSL - Michigan',
#  'Research Volunteer',
#  'Associate Scientist I/II - Synthetic Organic Chemist',
#  'Senior Chemist, Bioanalysis (R & D)',
#  'Anita Canada',
#  'Quality Control Project Manager/Scientist,Chemistry,Manufact.,Controls',
#  'General Physician',
#  'Medical Science Liaison, Rheumatology, Gastroenterology & Immunology- Michigan, Ohio',
#  'Radiologic Technologist - Mount Ephraim, NJ',
#  'Sr. Validation Engineer - EMERGNET BIOSOLUTIONS',
#  'Research Nurse II - Amended Repost',
#  '219 - Clinical Research Professional',
#  'Lead Biostatistician - Clinical Trials / DMC Required / Pharma (Remote, US)',
#  'Sr. Manager/Associate Director, Pharmacovigilance',
#  'Functional Analyst - Forte Group',
#  'Lead Clinical Research Associate',
#  'Clinical Research Associate - Alberta',
#  'Global Clinical Program Management Senior Manager Observational',
#  'Clinical Research Manager (Oncology)',
#  'Lab Patient Technician - Casual - SEIU',
#  'Medicinal Scientist/Senior Research Scientist',
#  'Lab Patient Technician Float - SK',
#  'Regulatory and Clinical Affairs Manager',
#  'Research Technician',
#  'Laboratory Assistant',
#  'Lead Scientist',
#  'Technologist Co-op',
#  'Rotational Pharmacy Technician',
#  'Laboratory Assistant - Part Time Regular Float - White Rock, Surrey, Delta',
#  'Sr Manager, Clinical Data Solutions',
#  'Global Medical Operations Manager - Performance Management',
#  'Risk Based Monitoring Manager',
#  'Associate Scientist - DMPK Bioanalysis',
#  'Experienced Clinical Research Professional actively looking for Clinical Research & Drug Safety jobs in Ontario, Canada',
#  'Water, Sanitation and Hygiene (WASH in Healthcare) Officer',
#  'Senior / Principal Scientist',
#  'Clinical Supervisor',
#  'Clinical Biomarker Sr. Manager, Clinical Operations (Infectious Disease)',
#  'Research Facilitator - Western Zone, Nova Scotia Health Authority',
#  'Administrative Assistant - Clinical',
#  'Senior Clinical Research Associate at PRA Health Sciences',
#  'Specialty Sales Representative, Omaha',
#  'Lab Patient Technician- Part Time',
#  'Lab Patient Technician- Temporary Part Time Regular',
#  'Laboratory Assistant - Vancouver',
#  'Founder and Scientist - Nanogenius Laboratories Inc',
#  'Biomedical Scientist - Microbiology/Molecular Biology',
#  'Senior Manager/ AD of Biostatistics',
#  'Senior Research Associate, Oncology - 1482',
#  'Senior Manager, Clinical Project Lead',
#  'Director of Activities',
#  'Independent Study in Organic Chemistry',
#  'Director, Translational Research (Biopharmaceuticals)',
#  'Home Support Worker',
#  'Clinical Research Associate - French-speaking (Rheumatoid & Psoriatic Arthritis)',
#  'CLINICAL RESEARCH INTERN',
#  'Medical Science Liaison, Ophthalmology- FL-PR',
#  'Family Nurse Practitioner',
#  'Registered Nurse- Infusions RN - PerCuro Clinical Research',
#  'Senior Manager, PV Operations Commercial & Study Liaison (PVCSL)',
#  'Regulatory Affairs Lead Consultant',
#  'Clinical Trial Coordinator',
#  'Research assistant',
#  'Quality Control Scientist - Sonoma Nutracueticals',
#  'Clinical Research Administrative Assistant',
#  'Director of Research Immunology',
#  'Director, Precision Medicine Clinical Biomarker Scientist',
#  'RESPIRATORY THER (TEMP)',
#  'Study Start-up Specialist- 1 Year Contract',
#  'Associate research scientist',
#  'Healthcare || Market Research || Data Science',
#  'Senior Manager, Early Development - Amgen',
#  'Associate Scientist, Research and Development - Catalent Pharma Solutions',
#  'Director of Wellness (RN or LPN) - Denver, CO',
#  'Production Technician',
#  'Statistical Science Director',
#  'RN Supervisor - Full Time',
#  'Technologist II',
#  'Administrative Assistant, Sunnybrook Research Institute',
#  'Scientist I/II, Cell/ Molecular Biologist',
#  'Manager, Clinical Supplies',
#  'General Duty Nuclear Medicine Technologist',
#  'MSL Field Director, Respiratory- West',
#  'Clinical Trials Manager',
#  'Medical Lab Technician/Assistant (Co-placement)',
#  'Registered Practical Nurse - London Health Science Centre',
#  'Toxicology - Research Scientist',
#  'Assoc Scientist/Scientist Translational Bioinformatics',
#  'Lab Patient Technician - SK',
#  'Clinical Research Associate / Snr Clinical Research Associate',
#  'Sanitation Technician',
#  'Research Coordinator - Department of Community Health Sciences',
#  'Support Worker - Doncaster',
#  'Research Director at Zoetis Inc.',
#  'CRC II, Cancer Clinical Trials',
#  'Registered Nurse, Experience Clinical Specialist/Nurse Educator',
#  'Medical Science Liaison - GSK',
#  'Coordinator - Research - Nursing - Research Oncology',
#  'Procurement Assistant',
#  'Senior/Principal Data Manager',
#  'Research Technician, Center for Immuno-Oncology',
#  'Supervisor Manager',
#  'Clinical Trial Assistant',
#  'Registered Nurse Quality Assurance',
#  'Clinical Research Associate/ Data Entry',
#  'Director/Senior Director, HEOR',
#  'Abbotsford - Registered Nurse Casual',
#  'Occupational Therapist-Repost',
#  'Clinical Trials IWRS Monitor, Toronto/Markham, Ontario, Canada',
#  'Housekeeper â€“ SHOAL Assisted Living â€“ Casual',
#  'Medical Lab Technologist - Insception Lifebank',
#  'Clinical Data Management Assistant',
#  'Synthetic Organic Chemist (Forensic Production Dept.)',
#  'MARKETING, SALES, PRODUCT, SERVICE, BUSINESS DEVELOPMENT, OPERATIONS AND FINANCIAL MANAGER AND LEADER',
#  'Lab Patient Technician- Temporary Regular Part Time Float',
#  '291 - Clinical Research Professional',
#  'Certified Medical Assistant - Clinical Trials Unit - 1.0 FTE',
#  'Laboratory Assistant- Part Time Regular Float',
#  'Research Internship',
#  'Clinical Trials Research Nurse I, Santa Clara, Full-time',
#  'Clinical Research Scientist - Oncology - Home Based',
#  'Clinical Research Associate (Placement-Edmonton/Calgary)',
#  'Senior Clinical Outsourcing Consultant',
#  'Caregiver for HASCI client in Columbia',
#  'Laboratory Assistant - Part Time Regular Float - Vancouver/Richmond',
#  'Bioinformatics Engineer/Scientist',
#  'Lab Patient Technician - Full Time - Mississauga (ON)',
#  'ANALYTICAL DEVELOPMENT SCIENTIST - Taro Pharmaceuticals Inc',
#  'Clinical Research Nurse Manager, Miami Cancer Institute, FT, 8A-4:30P',
#  'Director of Business Development - Bioanalytics',
#  'Patient Care Specialist Part-Time - Commonwealth Medical',
#  'Scientist, Cognitive Neurodegeneration',
#  'Site Contract Lead',
#  'Senior Manager Regional Clinical Trial Operations',
#  'Scientist, Veterinary Genomics',
#  ...}

# %%
'''Vectors Analysis:
---------------------
- skill_title :            3578 Job Titles   
- DocumentId :             7642 IDS
- Type:                    ['resume', 'job']
- OriginalTitle:            
- CreationDate:
- CreationDate:            5708 dates ['2020-04-05 03:56:11', .... , Timestamp('2005-10-15 00:00:00')]] 
- OriginalCompanyName:     Where the employee comes from
- RangeFrom:               
- RangeTo:

- OriginalSalary:

- OriginalLocation:
- CountryCode:
- City
- State

- SalaryParsed:          ["b'\\x00'", "b'\\x01'"] cannot use
- Complexity:            [nan,1.0,.... 10.0]      Ten grades of complexity
- importance:             [0.804382]



VARIABLES:
---------
Suply: Demand = Resume
       Supply = Job
       
Need to pull the most important jobs requested

- Develop an inventory of current skills that exist within the vaccine manufacturing space in Michigan
- Determine what are the evolving/new skills within the sector
- Identify supply and demand conditions within this laber market - in particular, the supply constrained skills.
- Identyfy geographic trends
- Provide any other insights that could be relevant.


'''
# Out:
# "Vectors Analysis:\n---------------------\n- skill_title :            3578 Job Titles   \n- DocumentId :             7642 IDS\n- Type:                    ['resume', 'job']\n- OriginalTitle:           5708 dates ['2020-04-05 03:56:11', .... , Timestamp('2005-10-15 00:00:00')]] \n- CreationDate:\n- OriginalCompanyName: \n- RangeFrom:\n- RangeTo:\n\n"

# %%
import datetime as dt
#CREATE INDEX FOR YEAR AND MONTH
df0['CreationDate'] = pd.to_datetime(df0['CreationDate'])
df0['year'] = pd.DatetimeIndex(df0['CreationDate']).year
df0['month'] = pd.DatetimeIndex(df0['CreationDate']).month

#CREATE INDEX FOR YEAR 2020
filterDate = [2020]
index_date = df0.year.isin(filterDate)

#CREATE NEW DATASET FOR 2020 ONLY
df1 = df0[index_date]
print("ALL DATES (df0 shape) = ",df0.shape, "\n","2020 ONLY (df1 shape) = ",df1.shape)
# Out:
# ALL DATES (df0 shape) =  (231713, 19)
#  2020 ONLY (df1 shape) =  (112744, 19)

# %%
#Supply of Jobs for 2020
#--------------
regex_supply = "resume"
series_supply = df1.iloc[:,2]
index_supply = series_supply.str.contains(regex_supply)
index_supply

#REMOVE NOT NEEDED DATES
#--------------------------
df1_supply = df1[index_supply]
print("SUPPLY (RESUME) = ",df1_supply.shape)
# Out:
# SUPPLY (RESUME) =  (3981, 19)

# %%
#Demand of Jobs for 2020
#--------------
regex_demand = "job"
series_demand = df1.iloc[:,2]
index_demand = series_demand.str.contains(regex_demand)
index_demand

#REMOVE NOT NEEDED DATES
#--------------------------
df1_demand = df1[index_demand]
print("DEMAND (JOBS) = ",df1_demand.shape)
# Out:
# DEMAND (JOBS) =  (108763, 19)

# %%
#RESUME - SUPPLY SKILLS NEEDED IN 2020
df2_supply = df1_supply.iloc[:,[0,1]]
df2_supply_agg = df2_supply.groupby('skill_title').count()
df2_supply_agg.sort_values(by='DocumentId', ascending=False)
# Out:
#                            DocumentId
# skill_title
# Research                           91
# Clinical Trials                    55
# Management                         54
# Biotechnology                      53
# parasitology                       50
# ...                               ...
# Predictive Modelling                1
# Policy Development                  1
# Physics                             1
# Personal Training                   1
# workplace safety planning           1
#
# [903 rows x 1 columns]

# %%
#JOBS - DEMAND SKILLS NEEDED IN 2020
df2_demand = df1_demand.iloc[:,[0,1]]
df2_demand_agg = df2_demand.groupby('skill_title').count()
df2_demand_agg.sort_values(by='DocumentId', ascending=False)
# Out:
#                          DocumentId
# skill_title
# Responsibility                 2023
# Management                     2007
# Clinical Trials                1972
# Communication Skills           1922
# Work Collaboratively           1581
# ...                             ...
# language instruction              1
# language interpretation           1
# layout planning                   1
# lead generation                   1
# .NET Core                         1
#
# [2420 rows x 1 columns]
