# %%
#https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=1410005801

import pandas as pd
df = pd.read_csv("unemployment.csv")

df.shape
# Out:
# (2069496, 17)

# %%
df.head(5)
# Out:
#   REF_DATE     GEO           DGUID Type of work sought and search method  \
# 0  1976-01  Canada  2016A000011124                      Total unemployed
# 1  1976-01  Canada  2016A000011124                      Total unemployed
# 2  1976-01  Canada  2016A000011124                      Total unemployed
# 3  1976-01  Canada  2016A000011124                      Total unemployed
# 4  1976-01  Canada  2016A000011124                      Total unemployed
#
#           Sex          Age group      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0  Both sexes  15 years and over  Persons     249     thousands          3
# 1  Both sexes     15 to 24 years  Persons     249     thousands          3
# 2  Both sexes  25 years and over  Persons     249     thousands          3
# 3  Both sexes     25 to 44 years  Persons     249     thousands          3
# 4  Both sexes  45 years and over  Persons     249     thousands          3
#
#      VECTOR COORDINATE  VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0  v3469253    1.1.1.1  815.7    NaN     NaN         NaN         1
# 1  v3469266    1.1.1.2  375.9    NaN     NaN         NaN         1
# 2  v3469279    1.1.1.3  439.8    NaN     NaN         NaN         1
# 3  v3469292    1.1.1.4  293.1    NaN     NaN         NaN         1
# 4  v3469305    1.1.1.5  146.7    NaN     NaN         NaN         1

# %%
#LIST OF ALL COLUMNS
list_col = list(df.columns)
list_col
# Out:
# ['REF_DATE',
#  'GEO',
#  'DGUID',
#  'Type of work sought and search method',
#  'Sex',
#  'Age group',
#  'UOM',
#  'UOM_ID',
#  'SCALAR_FACTOR',
#  'SCALAR_ID',
#  'VECTOR',
#  'COORDINATE',
#  'VALUE',
#  'STATUS',
#  'SYMBOL',
#  'TERMINATED',
#  'DECIMALS']

# %%
#SCHEEMA
df.dtypes
# Out:
# REF_DATE                                  object
# GEO                                       object
# DGUID                                     object
# Type of work sought and search method     object
# Sex                                       object
# Age group                                 object
# UOM                                       object
# UOM_ID                                     int64
# SCALAR_FACTOR                             object
# SCALAR_ID                                  int64
# VECTOR                                    object
# COORDINATE                                object
# VALUE                                    float64
# STATUS                                    object
# SYMBOL                                   float64
# TERMINATED                               float64
# DECIMALS                                   int64
# dtype: object

# %%
#REMOVE NOT NEEDED COLUMNS
#--------------------------
df1 = df.iloc[:,[0,1,3,4,5,12]]

# %%
#CHECK UNIQUE VALUES OF COLUMN
#------------------------------
listvalcol = set(list(df.iloc[:,5]))
listvalcol

#NOTE ABSOLUTE VALUES ARE INCLUDED IN THE DATASET, THIS MEANS THAT RECORDS ARE REPEATED.
# Out:
# {'15 to 24 years',
#  '15 years and over',
#  '25 to 44 years',
#  '25 to 54 years',
#  '25 years and over',
#  '45 years and over',
#  '55 to 64 years',
#  '55 years and over',
#  '65 years and over'}

# %%
#CREATE AN INDEX FOR ONLY 2020 and 2019 YEARS
#--------------------------------------------
regex_date = "2020.*|2019.*"
series_date = df1.iloc[:,0]
index_date = series_date.str.contains(regex_date)
index_date
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2069491     True
# 2069492     True
# 2069493     True
# 2069494     True
# 2069495     True
# Name: REF_DATE, Length: 2069496, dtype: bool

# %%
#REMOVE NOT NEEDED DATES
#--------------------------
df2 = df1[index_date]

# %%
#CREATE AN INDEX FOR ONLY "to" VALUES
#--------------------------------------------
regex_Age = ".*to.*|65 years and over"
series_Age = df2.iloc[:,4]
index_Age = series_Age.str.contains(regex_Age)
index_Age
# Out:
# 1992276    False
# 1992277     True
# 1992278    False
# 1992279     True
# 1992280    False
#            ...
# 2069491    False
# 2069492     True
# 2069493    False
# 2069494     True
# 2069495     True
# Name: Age group, Length: 77220, dtype: bool

# %%
#REMOVE NOT NEEDED Ages
#--------------------------
df3 = df2[index_Age]

# %%
#CREATE AN INDEX TO EXCLUDE "CANADA" FROM LOCATIONS
#--------------------------------------------
regex_location = "[^Canada]"
series_location = df3.iloc[:,1]
index_location = series_location.str.contains(regex_location)
index_location
# Out:
# 1992277    False
# 1992279    False
# 1992281    False
# 1992283    False
# 1992284    False
#            ...
# 2069488     True
# 2069490     True
# 2069492     True
# 2069494     True
# 2069495     True
# Name: GEO, Length: 42900, dtype: bool

# %%
#CREATE AN INDEX TO EXCLUDE "CANADA" FROM LOCATIONS
#--------------------------------------------
regex_location = "[^Canada]"
series_location = df3.iloc[:,1]
index_location = series_location.str.contains(regex_location)
index_location
# Out:
# 1992277    False
# 1992279    False
# 1992281    False
# 1992283    False
# 1992284    False
#            ...
# 2069488     True
# 2069490     True
# 2069492     True
# 2069494     True
# 2069495     True
# Name: GEO, Length: 42900, dtype: bool

# %%
df4 = df3[index_location]
df4
# Out:
#         REF_DATE                        GEO  \
# 1992628  2019-01  Newfoundland and Labrador
# 1992630  2019-01  Newfoundland and Labrador
# 1992632  2019-01  Newfoundland and Labrador
# 1992634  2019-01  Newfoundland and Labrador
# 1992635  2019-01  Newfoundland and Labrador
# ...          ...                        ...
# 2069488  2020-08           British Columbia
# 2069490  2020-08           British Columbia
# 2069492  2020-08           British Columbia
# 2069494  2020-08           British Columbia
# 2069495  2020-08           British Columbia
#
#         Type of work sought and search method         Sex          Age group  \
# 1992628                      Total unemployed  Both sexes     15 to 24 years
# 1992630                      Total unemployed  Both sexes     25 to 44 years
# 1992632                      Total unemployed  Both sexes     25 to 54 years
# 1992634                      Total unemployed  Both sexes     55 to 64 years
# 1992635                      Total unemployed  Both sexes  65 years and over
# ...                                       ...         ...                ...
# 2069488             Looked-used other methods     Females     15 to 24 years
# 2069490             Looked-used other methods     Females     25 to 44 years
# 2069492             Looked-used other methods     Females     25 to 54 years
# 2069494             Looked-used other methods     Females     55 to 64 years
# 2069495             Looked-used other methods     Females  65 years and over
#
#          VALUE
# 1992628    5.3
# 1992630   11.5
# 1992632   19.2
# 1992634    7.7
# 1992635    1.5
# ...        ...
# 2069488    4.0
# 2069490    9.2
# 2069492   13.0
# 2069494    NaN
# 2069495    NaN
#
# [39000 rows x 6 columns]

# %%
listvalcol = set(list(df4.iloc[:,4]))
listvalcol
# Out:
# {'15 to 24 years',
#  '25 to 44 years',
#  '25 to 54 years',
#  '55 to 64 years',
#  '65 years and over'}

# %%
#CLEAN GENDER BOTH ONE LINE INDEXING
#-----------------------------------
index_clean_sex = df4.pipe(lambda x: x['Sex'] != "Both sexes")
df5 = df4[index_clean_sex]
df5
# Out:
#         REF_DATE                        GEO  \
# 1992637  2019-01  Newfoundland and Labrador
# 1992639  2019-01  Newfoundland and Labrador
# 1992641  2019-01  Newfoundland and Labrador
# 1992643  2019-01  Newfoundland and Labrador
# 1992644  2019-01  Newfoundland and Labrador
# ...          ...                        ...
# 2069488  2020-08           British Columbia
# 2069490  2020-08           British Columbia
# 2069492  2020-08           British Columbia
# 2069494  2020-08           British Columbia
# 2069495  2020-08           British Columbia
#
#         Type of work sought and search method      Sex          Age group  \
# 1992637                      Total unemployed    Males     15 to 24 years
# 1992639                      Total unemployed    Males     25 to 44 years
# 1992641                      Total unemployed    Males     25 to 54 years
# 1992643                      Total unemployed    Males     55 to 64 years
# 1992644                      Total unemployed    Males  65 years and over
# ...                                       ...      ...                ...
# 2069488             Looked-used other methods  Females     15 to 24 years
# 2069490             Looked-used other methods  Females     25 to 44 years
# 2069492             Looked-used other methods  Females     25 to 54 years
# 2069494             Looked-used other methods  Females     55 to 64 years
# 2069495             Looked-used other methods  Females  65 years and over
#
#          VALUE
# 1992637    3.6
# 1992639    8.5
# 1992641   13.7
# 1992643    4.8
# 1992644    1.1
# ...        ...
# 2069488    4.0
# 2069490    9.2
# 2069492   13.0
# 2069494    NaN
# 2069495    NaN
#
# [26000 rows x 6 columns]

# %%
#RENAME COLUMNS
#--------------
df5 = df5.rename({
                'REF_DATE': 'date',
                'GEO': 'location',
                'Type of work sought and search method': 'search_method',
                'Sex': 'gender',
                'Age group': 'age',
                'VALUE': 'count_value'
}, axis='columns')

df5
# Out:
#             date                   location              search_method  \
# 1992637  2019-01  Newfoundland and Labrador           Total unemployed
# 1992639  2019-01  Newfoundland and Labrador           Total unemployed
# 1992641  2019-01  Newfoundland and Labrador           Total unemployed
# 1992643  2019-01  Newfoundland and Labrador           Total unemployed
# 1992644  2019-01  Newfoundland and Labrador           Total unemployed
# ...          ...                        ...                        ...
# 2069488  2020-08           British Columbia  Looked-used other methods
# 2069490  2020-08           British Columbia  Looked-used other methods
# 2069492  2020-08           British Columbia  Looked-used other methods
# 2069494  2020-08           British Columbia  Looked-used other methods
# 2069495  2020-08           British Columbia  Looked-used other methods
#
#           gender                age  count_value
# 1992637    Males     15 to 24 years          3.6
# 1992639    Males     25 to 44 years          8.5
# 1992641    Males     25 to 54 years         13.7
# 1992643    Males     55 to 64 years          4.8
# 1992644    Males  65 years and over          1.1
# ...          ...                ...          ...
# 2069488  Females     15 to 24 years          4.0
# 2069490  Females     25 to 44 years          9.2
# 2069492  Females     25 to 54 years         13.0
# 2069494  Females     55 to 64 years          NaN
# 2069495  Females  65 years and over          NaN
#
# [26000 rows x 6 columns]

# %%
#VALIDATION GROUP BY search_method
#--------------
df5.groupby(['date']).sum()
# Out:
#          count_value
# date
# 2019-01       6595.0
# 2019-02       6518.1
# 2019-03       6574.8
# 2019-04       6416.1
# 2019-05       5910.1
# 2019-06       5778.9
# 2019-07       6450.8
# 2019-08       6659.8
# 2019-09       5527.6
# 2019-10       5484.6
# 2019-11       6079.3
# 2019-12       5609.7
# 2020-01       6302.6
# 2020-02       6536.3
# 2020-03       8071.9
# 2020-04      10338.8
# 2020-05      12042.4
# 2020-06      11854.4
# 2020-07      12122.1
# 2020-08      12049.4

# %%
#VALIDATION - PERCENTAGE OF TOTAL
#---------- -- -----
Total = df5['count_value'].sum()
x = df5.groupby(['location','gender','age']).sum()
x/Total
# Out:
#                                         count_value
# location     gender  age
# Alberta      Females 15 to 24 years        0.012025
#                      25 to 44 years        0.020355
#                      25 to 54 years        0.027510
#                      55 to 64 years        0.006842
#                      65 years and over     0.000252
# ...                                             ...
# Saskatchewan Males   15 to 24 years        0.003306
#                      25 to 44 years        0.004755
#                      25 to 54 years        0.006138
#                      55 to 64 years        0.001257
#                      65 years and over     0.000207
#
# [100 rows x 1 columns]

# %%
#CHANGE count datatype to int currently is float64 because there are nan values
import numpy as np
df5['count_value'] = df5['count_value'].fillna(0).astype(np.int64)

#CHANGE date datatype date, currently is string
import datetime
df5['date'] = pd.to_datetime(df5['date'])

# %%
#OUTPUT DATAFRAME
#(df5).to_csv('unemployment_dataSet.csv', sep = ',', index=False)

# %%
#CHECK IF THERE ARE DUPLICATES IN THE ORIGINAL DATAFRAME
dfs.head(5)
# Out:
#                                       REF_DATE     GEO           DGUID  \
# Type of work sought and search method
# Total unemployed                       1976-01  Canada  2016A000011124
# Total unemployed                       1976-01  Canada  2016A000011124
# Total unemployed                       1976-01  Canada  2016A000011124
# Total unemployed                       1976-01  Canada  2016A000011124
# Total unemployed                       1976-01  Canada  2016A000011124
#
#                                               Sex          Age group      UOM  \
# Type of work sought and search method
# Total unemployed                       Both sexes  15 years and over  Persons
# Total unemployed                       Both sexes     15 to 24 years  Persons
# Total unemployed                       Both sexes  25 years and over  Persons
# Total unemployed                       Both sexes     25 to 44 years  Persons
# Total unemployed                       Both sexes  45 years and over  Persons
#
#                                        UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# Type of work sought and search method
# Total unemployed                          249     thousands          3
# Total unemployed                          249     thousands          3
# Total unemployed                          249     thousands          3
# Total unemployed                          249     thousands          3
# Total unemployed                          249     thousands          3
#
#                                          VECTOR COORDINATE  VALUE STATUS  \
# Type of work sought and search method
# Total unemployed                       v3469253    1.1.1.1  815.7    NaN
# Total unemployed                       v3469266    1.1.1.2  375.9    NaN
# Total unemployed                       v3469279    1.1.1.3  439.8    NaN
# Total unemployed                       v3469292    1.1.1.4  293.1    NaN
# Total unemployed                       v3469305    1.1.1.5  146.7    NaN
#
#                                        SYMBOL  TERMINATED  DECIMALS
# Type of work sought and search method
# Total unemployed                          NaN         NaN         1
# Total unemployed                          NaN         NaN         1
# Total unemployed                          NaN         NaN         1
# Total unemployed                          NaN         NaN         1
# Total unemployed                          NaN         NaN         1

# %%
#CHECK IF THERE ARE DUPLICATED ROWS

def dupsAndclean(dfs):
    dups_var = dfs[dfs.duplicated(subset = None, keep = 'last')]
    clean_var = dfs.drop_duplicates()
    print("INFO")
    print(60*"-")
    print("Dataframe shape with no dups: ",clean_var.shape)
    print("Dataframe composed of duplicates shape: ",dups_var.shape)
    print("Total missing rows after removing dups ",dups_var.shape[0])
    
dupsAndclean(df1)
# Out:
# INFO
# ------------------------------------------------------------
# Dataframe shape with no dups:  (2069496, 6)
# Dataframe composed of duplicates shape:  (0, 6)
# Total missing rows after removing dups  0

# %%
#RETURN DUPLICATED ROWS AND CLEAN DATAFRAME
def removeDups(dfs):
    dups_var = dfs[dfs.duplicated(subset = None, keep = 'last')]
    clean_var = dfs.drop_duplicates()
    return [dups_var,clean_var]

#DUPLICATED ROwS
print(removeDups(df1)[0])

#CLEAN DATAFRAME
print(removeDups(df1)[1])
# Out:
# Empty DataFrame
# Columns: [REF_DATE, GEO, Type of work sought and search method, Sex, Age group, VALUE]
# Index: []
#         REF_DATE               GEO Type of work sought and search method  \
# 0        1976-01            Canada                      Total unemployed
# 1        1976-01            Canada                      Total unemployed
# 2        1976-01            Canada                      Total unemployed
# 3        1976-01            Canada                      Total unemployed
# 4        1976-01            Canada                      Total unemployed
# ...          ...               ...                                   ...
# 2069491  2020-08  British Columbia             Looked-used other methods
# 2069492  2020-08  British Columbia             Looked-used other methods
# 2069493  2020-08  British Columbia             Looked-used other methods
# 2069494  2020-08  British Columbia             Looked-used other methods
# 2069495  2020-08  British Columbia             Looked-used other methods
#
#                 Sex          Age group  VALUE
# 0        Both sexes  15 years and over  815.7
# 1        Both sexes     15 to 24 years  375.9
# 2        Both sexes  25 years and over  439.8
# 3        Both sexes     25 to 44 years  293.1
# 4        Both sexes  45 years and over  146.7
# ...             ...                ...    ...
# 2069491     Females  45 years and over    5.6
# 2069492     Females     25 to 54 years   13.0
# 2069493     Females  55 years and over    1.8
# 2069494     Females     55 to 64 years    NaN
# 2069495     Females  65 years and over    NaN
#
# [2069496 rows x 6 columns]

# %%
#TEST GROUP BY SUM
#----------------
df.groupby(['Type of work sought and search method']).sum()
# Out:
#                                                  UOM_ID  SCALAR_ID      VALUE  \
# Type of work sought and search method
# Future job starter                             39638808     477576   301398.4
# Looked for full-time work                      39638808     477576  6960581.9
# Looked for part-time work                      39638808     477576  1360514.3
# Looked-checked with employers directly         39638808     477576  4919678.3
# Looked-checked with friends or relatives       39638808     477576  1565430.5
# Looked-checked with private employment agency  39638808     477576   482989.8
# Looked-checked with union                      39638808     477576   225151.5
# Looked-looked at job ads                       39638808     477576  4322207.9
# Looked-placed or answered ads                  39638808     477576  1945590.5
# Looked-used other methods                      39638808     477576   794375.8
# Looked-used public employment agency           39638808     477576  2584163.4
# On temporary layoff                            39638808     477576   656283.8
# Total unemployed                               39638808     477576  9335402.3
#
#                                                SYMBOL  TERMINATED  DECIMALS
# Type of work sought and search method
# Future job starter                                0.0         0.0    159192
# Looked for full-time work                         0.0         0.0    159192
# Looked for part-time work                         0.0         0.0    159192
# Looked-checked with employers directly            0.0         0.0    159192
# Looked-checked with friends or relatives          0.0         0.0    159192
# Looked-checked with private employment agency     0.0         0.0    159192
# Looked-checked with union                         0.0         0.0    159192
# Looked-looked at job ads                          0.0         0.0    159192
# Looked-placed or answered ads                     0.0         0.0    159192
# Looked-used other methods                         0.0         0.0    159192
# Looked-used public employment agency              0.0         0.0    159192
# On temporary layoff                               0.0         0.0    159192
# Total unemployed                                  0.0         0.0    159192

# %%
#TEST GROUP BY SUM RETURN ONE COLUMN COLUMN
#-------------------------------------------
dfs = df.set_index(['Type of work sought and search method'])
dfs['VALUE'].groupby(['Type of work sought and search method']).sum()
# Out:
# Type of work sought and search method
# Future job starter                                301398.4
# Looked for full-time work                        6960581.9
# Looked for part-time work                        1360514.3
# Looked-checked with employers directly           4919678.3
# Looked-checked with friends or relatives         1565430.5
# Looked-checked with private employment agency     482989.8
# Looked-checked with union                         225151.5
# Looked-looked at job ads                         4322207.9
# Looked-placed or answered ads                    1945590.5
# Looked-used other methods                         794375.8
# Looked-used public employment agency             2584163.4
# On temporary layoff                               656283.8
# Total unemployed                                 9335402.3
# Name: VALUE, dtype: float64

# %%
#Put a GroupBY into a Dataframe
grouped = pd.DataFrame(dfs['VALUE'].groupby(['Type of work sought and search method']).sum().reset_index())

# %%
#CHECK THAT TOTAL UNEMPLOYMENT = TO THE REST OF THE ELEMENTS
index_No_Total = grouped.pipe(lambda x: x['Type of work sought and search method'] != "Total unemployed")
index_TOTAL = grouped.pipe(lambda x: x['Type of work sought and search method'] == "Total unemployed")
grouped1 = grouped[index_No_Total]['VALUE']
grouped2 = grouped[index_TOTAL]['VALUE']

grouped1.sum() - grouped2.sum()
# Out:
# 16782963.800000213

# %%
#=================================
#CREATING A NESTED FOR ALL VALUES
#=================================
'''
Checking values
'''
df5
df5.groupby(['date','location','age','gender']).sum()
# Out:
#                                                    count_value
# date       location     age               gender
# 2019-01-01 Alberta      15 to 24 years    Females           47
#                                           Males             77
#                         25 to 44 years    Females          125
#                                           Males            185
#                         25 to 54 years    Females          165
# ...                                                        ...
# 2020-08-01 Saskatchewan 25 to 54 years    Males             39
#                         55 to 64 years    Females           10
#                                           Males              9
#                         65 years and over Females            0
#                                           Males              2
#
# [2000 rows x 1 columns]

# %%
#=================================
#CREATING A NESTED FOR ALL VALUES
#=================================
'''
create a groupby .sum() for all locations
'''
grouped = pd.DataFrame(dfs['VALUE'].groupby(['Type of work sought and search method']).sum().reset_index())
grouped_all_locations = pd.DataFrame(df5.groupby(['date','age','gender']).sum().reset_index())
'''
insert column at location at index 1
add hardcoded column 'all locations to new table'

df.insert(1,'name_of_column',value)
'''
grouped_all_locations.insert(1,'location','ALL')
grouped_all_locations
# Out:
#           date location                age   gender  count_value
# 0   2019-01-01      ALL     15 to 24 years  Females          417
# 1   2019-01-01      ALL     15 to 24 years    Males          657
# 2   2019-01-01      ALL     25 to 44 years  Females          783
# 3   2019-01-01      ALL     25 to 44 years    Males         1041
# 4   2019-01-01      ALL     25 to 54 years  Females         1093
# ..         ...      ...                ...      ...          ...
# 195 2020-08-01      ALL     25 to 54 years    Males         2127
# 196 2020-08-01      ALL     55 to 64 years  Females          471
# 197 2020-08-01      ALL     55 to 64 years    Males          525
# 198 2020-08-01      ALL  65 years and over  Females           64
# 199 2020-08-01      ALL  65 years and over    Males          122
#
# [200 rows x 5 columns]

# %%
#test
index_DATES_2019 = df1.pipe(lambda x: x['REF_DATE'] != "Canada")
index_ALL_CANADA = df1.pipe(lambda x: x['GEO'] == "Canada")


test['VALUE'].groupby(['REF_DATE']).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-165-021bba9e20c7> in <module>
#       1 #test
#       2 test = df1.set_index(['GEO'])
# ----> 3 test['VALUE'].groupby(['REF_DATE']).sum()
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    1676         axis = self._get_axis_number(axis)
#    1677
# -> 1678         return groupby_generic.SeriesGroupBy(
#    1679             obj=self,
#    1680             keys=by,
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     401             from pandas.core.groupby.grouper import get_grouper
#     402
# --> 403             grouper, exclusions, obj = get_grouper(
#     404                 obj,
#     405                 keys,
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     598                 in_axis, name, level, gpr = False, None, gpr, None
#     599             else:
# --> 600                 raise KeyError(gpr)
#     601         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     602             # Add key to exclusions
#
# KeyError: 'REF_DATE'
